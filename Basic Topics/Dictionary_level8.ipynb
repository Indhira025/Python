# %%
len({"a":1, "b":2, "c":3})  # 4
# Out:
# 3

# %%
dict1 = {"name": "John", "age": 22}   # 6
dict1["name"]
# Out:
# 'John'

# %%
list({"x":1, "y":2})   # 11
# Out:
# ['x', 'y']

# %%
{"a":1, "b":2}.get("c", 5)   # 16
# Out:
# 5

# %%
max({"a":10, "b":20, "c":5})   # 26
# Out:
# 'c'

# %%
d = {"x": 10, "y": 20}    # 28
d["x"] += 5
print(d["x"])
# Out:
# 15

# %%
  # Section B – Coding Questions (20 Questions)
 # 1. Create a dictionary with 3 key-value pairs and print it.

d = {'name': 'mouni', 'age': 25, 'height': 5.5}
print(d)
# Out:
# {'name': 'mouni', 'age': 25, 'height': 5.5}

# %%
 # 2. Access and print the value of a specific key from a dictionary.

d = {'name': 'mouni', 'age': 25, 'height': 5.5}
print(d['height'])
# Out:
# 5.5

# %%
 # 3. Use get() to retrieve a value safely without causing an error.

a = {1:100,2:200,3:300,4:400}
print(a.get(3))
# Out:
# 300

# %%
 # 4. Merge two dictionaries into a new one using update().

a = { 1:50 , 2: 25 , 3:15 }
a[4]=5
print(a)
# Out:
# {1: 50, 2: 25, 3: 15, 4: 5}

# %%
 # 5. Remove a specific key using pop() and print the updated dictionary.

d = {1: 50, 2: 25, 3: 15, 4: 5}
d.pop(3)
print(d)
# Out:
# {1: 50, 2: 25, 4: 5}

# %%
 # 6. Check if a key exists in a dictionary using in operator.


d = {1: 50, 2: 25, 3: 15, 4: 5}
print(2 in d)
print(4 not in d)
print(1 in d)
# Out:
# True
# False
# True

# %%
 # 7. Retrieve all the keys from a dictionary using keys() method.

d = {'a': 20, 'b': 10, 'c': [1, 2, 3]}
print(d.keys())
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
 # 8. Retrieve all the values from a dictionary using values() method.

d = {'a': 20, 'b': 10, 'c': [1, 2, 3]}
print(d.values())
# Out:
# dict_values([20, 10, [1, 2, 3]])

# %%
 # 9. Get all key-value pairs from a dictionary using items().

a = {1 : 'python' , 2 : "java" , 3: 'c++' , 4: 'data analytics'}
print(a.items())
# Out:
# dict_items([(1, 'python'), (2, 'java'), (3, 'c++'), (4, 'data analytics')])

# %%
 # 10. Create a copy of a dictionary and verify both are independent.

d = {1: 50, 2: 25, 3: 15, 4: 5}
dict1 = d.copy()

print(d)
print(dict1)

print(id(d))
print(id(dict1))

d[5]=10

print(d)
print(dict1)
# Out:
# {1: 50, 2: 25, 3: 15, 4: 5}
# {1: 50, 2: 25, 3: 15, 4: 5}
# 137214229025472
# 137214229028928
# {1: 50, 2: 25, 3: 15, 4: 5, 5: 10}
# {1: 50, 2: 25, 3: 15, 4: 5}

# %%
 # 11. Use setdefault() to insert a key only if it doesn’t exist.

d = {"name": "John", "age": 22}
d.setdefault("city", "New York")
print(d)
# Out:
# {'name': 'John', 'age': 22, 'city': 'New York'}

# %%
 # 12. Convert a list of tuples [("a",1),("b",2)] into a dictionary.

t = [("a",1),("b",2)]
print(type(t))
d = dict(t)
print(d)
print(type(d))
# Out:
# <class 'list'>
# {'a': 1, 'b': 2}
# <class 'dict'>

# %%
 # 13. Convert two lists ["a","b"] and [1,2] into a dictionary.

list1 = ["a", "b"]
list2 = [1, 2]
result = dict(zip(list1, list2))
print(result)
# Out:
# {'a': 1, 'b': 2}

# %%
 # 14. Find the length of a dictionary using len().

d = {"name": "John", "age": 22}
print(len(d))
# Out:
# 2

# %%
 # 15.  Delete all items from a dictionary using clear().

d = {1: 50, 2: 25, 3: 15, 4: 5}
d.clear()
print(d)
# Out:
# {}

# %%
 # 16. Extract keys as a list and slice the first two.

a = {'Name' : ['mouni','likki','annu' , 'sowmya'] ,
     'Age' : [22,23,21,24] ,
     'height' : [5.5 , 5.8 , 5.0 , 5.2]
     }
print(a['Age'][0:4])
print(a['Age'][0:2])
# Out:
# [22, 23, 21, 24]
# [22, 23]

# %%
 # 17. Sort the dictionary by keys and display it.

d = {2: 'mouni' , 4: 'likki' , 1: 'annu' , 3: 'sowmya'}
print(d.keys())
print(sorted(d,reverse=False))
# Out:
# dict_keys([2, 4, 1, 3])
# [1, 2, 3, 4]

# %%
 # 18. Access a nested dictionary value, e.g., {"emp":{"name":"John","age":30}}.

d = {"emp":{"name":"John","age":30}}
print(d['emp']['age'])
print(d['emp']['name'])
# Out:
# 30
# John

# %%
 # 19. Use dictionary comprehension (without loops) to create a dictionary from a string using dict(zip()).

s = "abcd"
values = [1, 2, 3, 4]
d = dict(zip(s, values))
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
 # 20. Find the maximum and minimum value in a dictionary using built-in functions.

d = {1: 50, 2: 25, 3: 15, 4: 5}
max_value = max(d.values())
min_value = min(d.values())

print("Maximum value:", max_value)
print("Minimum value:", min_value)
# Out:
# Maximum value: 50
# Minimum value: 5
