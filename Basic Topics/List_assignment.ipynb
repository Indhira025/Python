# %%
lst = [10,20,30]  # 4
lst.pop(2)
# lst.remove(2)
# del lst(2)
print(lst)
# Out:
# [10, 20]

# %%
a = len([5,6,7])   # 11
print('len: ', a)

b = min([4,9,2,7])   # 12
print('min: ',b)

c = sum([1,2,3])     # 13
print('sum: ',c)
# Out:
# len:  3
# min:  2
# sum:  6

# %%
"python".split()    # 15
# Out:
# ['python']

# %%
list = [10,20,30]      # 17
list.reverse()
print(list)
# Out:
# [30, 20, 10]

# %%
len([[],[1,2],3])    # 18
# Out:
# 3

# %%
[1,2]*2      # 22
# Out:
# [1, 2, 1, 2]

# %%
['a','b','c'][1:]     # 24
# Out:
# ['b', 'c']

# %%
sorted([3,1,2])    # 26
# Out:
# [1, 2, 3]

# %%
[] is []   # 28
# Out:
# False

# %%
list('abc')    # 29
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3877025095.py in <cell line: 0>()
# ----> 1 list('abc')
#
# TypeError: 'list' object is not callable

# %%
        # Coding Questions (no loops)
  # 1. Access the 3rd element of a list.

l = [10,20,30,40,50]
print(l[2])
# Out:
# 30

# %%
 # 2. Print the last element without using negative index.

l = [10,20,30,40,50]
print(l[4:])
# Out:
# [50]

# %%
 # 3. Slice a list to get first three items.

l = [10,20,30,40,50]
print(l[:3])
# Out:
# [10, 20, 30]

# %%
 # 4. Slice to get every second element.

l = [10,20,30,40,50]
print(l[::2])
# Out:
# [10, 30, 50]

# %%
 # 5. Reverse a list using slicing.

l = [10,20,30,40,50]
print(l[::-1])
# Out:
# [50, 40, 30, 20, 10]

# %%
 # 6. Create a shallow copy of a list.

l = [10,20,30,40,50]
l1 = l.copy()

print(l)
print(l1)

print(id(l))
print(id(l1))

l.append(100)

print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, 20, 30, 40, 50]
# 139133324431616
# 139133324498560
# [10, 20, 30, 40, 50, 100]
# [10, 20, 30, 40, 50]

# %%
 # 7.Find length of a list.

s = [12,50,52,40,80,75]
print(len(s))
# Out:
# 6

# %%
 # 8. Find max value in a list.

lst = [12,56,85,21,12,20]
print(max(lst))
# Out:
# 85

# %%
 # 9. Find min value in a list.

lst = [12,45,85,23,11,45]
print(min(lst))
# Out:
# 11

# %%
 # 10. Remove the last element from a list.

a = [10,50,20,70,65]
a.pop(-1)
print(a)
# Out:
# [10, 50, 20, 70]

# %%
 # 11.Add an item to end of list.

lst = [12,45,85,60,45,23]
lst.append(100)
print(lst)
# Out:
# [12, 45, 85, 60, 45, 23, 100]

# %%
 # 12.Insert element at index 1.

lst = [45,60,85,47]
lst.insert(1,50)
print(lst)
# Out:
# [45, 50, 60, 85, 47]

# %%
 # 13.Convert string to list of characters.

s = 'data science'
print(type(s))
lst = list(s)
print(lst)
print(type(lst))
# Out:
# <class 'str'>
# ['d', 'a', 't', 'a', ' ', 's', 'c', 'i', 'e', 'n', 'c', 'e']
# <class 'list'>

# %%
 # 14.Convert string "a b c" to ['a','b','c'].

s = 'a b c'
lst = s.split()
print(lst)
# Out:
# ['a', 'b', 'c']

# %%
 # 15. Concatenate two lists.

lst1 = [12,45,85]
lst2 = [20,31,69]
lst = lst1 + lst2
print(lst)
# Out:
# [12, 45, 85, 20, 31, 69]

# %%
 # 16. Check if value exists in list.

lst = [45,48,75]
if 45 in lst:
  print('value exists in list')
else:
  print('value not exists in list')
# Out:
# value exists in list

# %%
 # 17. Create a list from 1-5 using list constructor.

# %%
 # 18.Remove an item by value.

lst = [20,60,80,59,32]
lst.remove(80)
print(lst)
# Out:
# [20, 60, 59, 32]

# %%
 # 19. Clear all elements of a list.

lst =[12,52,45,80]
lst.clear()
print(lst)
# Out:
# []

# %%
 # 20. Sort a list without modifying original list.

lst = [25,65,15,78,20,10]
lst.sort()
print(lst)
# Out:
# [10, 15, 20, 25, 65, 78]
